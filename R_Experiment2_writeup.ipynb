# %%
mkdir('myworkplace')
# Out:
# Error in mkdir("myworkplace"): could not find function "mkdir"
# Traceback:

# %%
getwd()
# Out:
# [1] "/content"

# %%
dir()
# Out:
# [1] "sample_data"

# %%
list.files()
# Out:
# [1] "sample_data"
